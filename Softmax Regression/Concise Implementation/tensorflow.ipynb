# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavgupta1/Dive-Into-Deep-Learning/blob/main/Softmax%20Regression/Concise%20Implementation/tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Softmax Regression

# %%
# !pip install d2l==0.16.1

# %%
from d2l import tensorflow as d2l
import tensorflow as tf

# %% [markdown]
# ### Reading the minibatch

# %%
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %%
n = 9
for X, y in train_iter:
  break;
d2l.show_images(tf.reshape(X[0:n], (n, 28, 28)), 1, n, titles=d2l.get_fashion_mnist_labels(y))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fadacfbb978>,
# ...
#       dtype=object)

# %% [markdown]
# ###Initializing Model Parameters

# %%
net = tf.keras.models.Sequential()
net.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
weight_initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.01)
net.add(tf.keras.layers.Dense(10, kernel_initializer=weight_initializer))

# %% [markdown]
# ### Defining the Loss Function

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %% [markdown]
# ### Optimization Algorithm

# %%
trainer = tf.keras.optimizers.SGD(learning_rate=.1)

# %% [markdown]
# ### Training

# %%
num_epochs = 10
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
def predict(net, test_iter, n=6):  #@save
    """Predict labels (defined in Chapter 3)."""
    for X, y in test_iter:
        break
    trues = d2l.get_fashion_mnist_labels(y)
    preds = d2l.get_fashion_mnist_labels(tf.argmax(net(X), axis=1))
    titles = [true +'\n' + pred for true, pred in zip(trues, preds)]
    d2l.show_images(tf.reshape(X[0:n], (n, 28, 28)), 1, n, titles=titles[0:n])

# %%
predict(net, test_iter, n=11)
