# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavgupta1/Dive-Into-Deep-Learning/blob/main/Multilayer%20Perceptrons/Concise%20Implementation/mxnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi Layer Percetrons

# %%
# !pip install d2l==0.16.1
# !pip install -U mxnet-cu101==1.7.0

# %%
from d2l import mxnet as d2l
from mxnet import gluon, init, npx
from mxnet.gluon import nn
npx.set_np()

# %% [markdown]
# ### Reading Data

# %%
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %% [markdown]
# ### Net

# %%
net = nn.Sequential()
net.add(nn.Dense(256, activation='relu'),nn.Dense(10))
net.initialize(init.Normal(sigma=0.01))

# %% [markdown]
# ###  Loss Function

# %%
loss = gluon.loss.SoftmaxCrossEntropyLoss()

# %% [markdown]
# ### Optimization Algorithm

# %%
lr = 0.1

# %%
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})

# %% [markdown]
# ### Training

# %%
num_epochs = 10
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %% [markdown]
# ### Prediction

# %%
d2l.predict_ch3(net, test_iter,n=11)
